# %%
이 자료는 고등학생 여러분이 데이터를 수집하고, 분석하고, 예측 모델로 활용하는 전 과정을  
직접 체험할 수 있도록 구성된 실습 중심의 융합형 AI 학습 자료입니다.

기후 변화, 작물 재배, 유전자 정보 등 현실 속 데이터를 활용하며  
수학적 사고, 과학적 탐구, 그리고 인공지능 알고리즘의 기본 개념을 자연스럽게 익히게 됩니다.

각 내용은 "왜 이 문제를 다루는가"라는 질문에서 시작해,  
"어떻게 접근할 수 있을까", "그 결과로 우리는 무엇을 알 수 있는가"를 단계적으로 풀어가며,  
학생 스스로 사고하고 실험하고 결론을 도출하는 흐름으로 구성되어 있습니다.

---

먼저 데이터를 다루는 이유와 의미부터 살펴봅니다.  
기온, 강수량, 이산화탄소 농도, 유전자 염기서열처럼 다양한 형태의 데이터를 직접 다뤄보면서  
숫자와 기호를 통해 세상을 설명하는 감각을 익히게 됩니다.

다음으로는 데이터를 눈으로 해석하는 능력을 기릅니다.  
막대그래프, 산점도, 색상 시각화, 지도 시각화를 통해  
숫자 속에 숨겨진 패턴을 드러내고, 직관적인 판단과 비교가 가능하도록 연습합니다.

기후 데이터를 바탕으로 작물을 추천하는 활동에서는  
복잡한 수학이 아니라, 가까운 조건을 기준으로 판단하는 K-최근접 이웃 알고리즘을 사용해  
데이터 기반 분류의 기본 원리를 익힙니다.

예측 모델을 더 정교하게 만들기 위해  
선형 회귀와 경사하강법을 이용하여 오차를 줄이는 방법도 실습합니다.  
이 과정을 통해 인공지능이 '학습한다'는 것이 어떤 원리인지 몸으로 이해하게 됩니다.

생명과학과 연결되는 활동도 포함되어 있습니다.  
DNA 염기서열을 데이터처럼 분석하고,  
염기의 빈도, 코돈의 구조, 단백질로의 변환 과정을 시각화하면서  
생물학적 정보의 구조와 의미를 탐색합니다.

로지스틱 회귀나 KNN 같은 알고리즘을 유전자 정보에 적용하는 실습에서는  
병에 걸릴 가능성, 특정 유전자가 어느 그룹에 속할지를 예측해보며  
단순한 코딩을 넘어서 사고하는 모델링 능력을 키우게 됩니다.

모든 실습은 단지 코드를 실행하는 것에 그치지 않고  
왜 그런 방식으로 풀었는지, 다른 선택은 가능했는지,  
그리고 이 모델이 어떤 가정을 전제로 하고 있는지를 묻는 질문과 함께 정리되어 있습니다.

---

이 자료는 기술을 배우기 위한 것이 아닙니다.  
데이터로 세상을 이해하고, 문제를 해석하며,  
수학과 컴퓨터 사고를 현실의 문제와 연결하는 경험을 제공하기 위해 만들어졌습니다.

여러 분야가 만나는 지점에서  
여러분은 질문하고 탐색하며  
AI 시대를 살아가는 데 꼭 필요한 통합적 사고력을 기르게 될 것입니다.

이 자료가 여러분의 배움과 도전에 작은 출발점이 되기를 바랍니다.

제작 및 진행: 백대성 (젤리코딩 원장)  
이메일: dsbaek898@icloud.com
# Out:
#   Cell In[5], line 1
#     이 자료는 고등학생 여러분이 데이터를 수집하고, 분석하고, 예측 모델로 활용하는 전 과정을
#       ^
# SyntaxError: invalid syntax
